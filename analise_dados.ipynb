# %%
import pandas as pd

# %%
df = pd.read_csv("data/processed/csv_tratado.csv")

# %%
df
# Out:
#       id_meeting           dt_meeting formato_meeting  id_status_meeting  \
# 0        1247082  2026-03-18 16:00:00           VIDEO                  3
# 1         989351  2026-01-28 15:30:00           VIDEO                  3
# 2        1027294  2026-02-11 14:00:00           VIDEO                  3
# 3         907223  2026-01-12 15:00:00           VIDEO                  3
# 4        1273662  2026-03-25 15:00:00           VIDEO                  3
# ...          ...                  ...             ...                ...
# 1121      982930  2026-01-28 11:00:00           VIDEO                  3
# 1122      721888  2025-11-24 10:00:00           VIDEO                  3
# 1123     1148526  2026-03-05 15:30:00           VIDEO                  3
# 1124     1148524  2026-03-05 15:30:00           VIDEO                  3
# 1125     1009619  2026-02-05 16:00:00           VIDEO                  3
#
#      status_meeting duracao_meeting    codt tp_recurso  flg_externo  \
# ...

# %%
print(df.isna().sum())
print(df["anon_transcricao"].isna().sum())
# Out:
# id_meeting                        0
# dt_meeting                        0
# formato_meeting                   0
# id_status_meeting                 0
# status_meeting                    0
# duracao_meeting                   0
# codt                              0
# tp_recurso                      895
# flg_externo                       0
# dt_criacao                        0
# anon_transcricao                  0
# uf                              417
# cnae                            417
# nome_unidade                    417
# nome_segmento                   417
# faixa_faturamento_cliente_ec    471
# dt_ultima_pesquisa              816
# nota_nps                        816
# dtype: int64
# 0
